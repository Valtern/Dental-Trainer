# %% [markdown]
# <a href="https://colab.research.google.com/github/Valtern/Dental-Trainer/blob/main/Dental_Trainer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# upload sonata_baseline_v1.zip to /content/

# !unzip -q sonata_baseline_v1.zip -d /content/

# %cd /content/sonata_baseline_v1

# !pip install -r requirements.txt

# !nvidia-smi

# !python scripts/train_colab_baseline.py --preflight-only
# Out:
# /content/sonata_baseline_v1
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 48.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 kB 8.3 MB/s eta 0:00:00
# ...
# Wed Sep 16 07:21:08 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# ...

# %%
# !python scripts/train_colab_baseline.py
# Out:
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.
# New https://pypi.org/project/ultralytics/8.4.153 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.150 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import shutil
from google.colab import files

# 1. Compress the folder into runs.zip
shutil.make_archive("runs", "zip", "/content/sonata_baseline_v1/runs/baseline/sonata_baseline_v1")

# 2. Trigger the browser download
files.download("runs.zip")
